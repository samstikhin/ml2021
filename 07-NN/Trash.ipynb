# %%
from seaborn import heatmap
n = 20
X = np.array([[[x1, x2] for x1 in np.linspace(-3,3,n)] 
                        for x2 in np.linspace(-3,3,n)[::-1]]).reshape((n*n,2))
tX = torch.FloatTensor(X)
result = f(h(tX)).detach().numpy().reshape(n,n)
heatmap(result)
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import Perceptron

X_clf, y_clf = get_clf_dataset(n=200)
clf = Perceptron().fit(X_clf, y_clf)
plt.figure(figsize=(7, 7))
plot_model(X_clf, y_clf, clf, proba=False)
# Out:
# Perceptron()
