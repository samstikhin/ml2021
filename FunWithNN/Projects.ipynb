# %% [markdown]
# # Набор доп баллов
# Разбор сложного туториала с результатом можно оценить от 5 до 15 баллов. Сдать 5 июня в универе.

# %% [markdown]
# # Проекты

# %% [markdown]
# ## [Проекты Антона Кошелева](https://t.me/mathmechgr/983)
#
# Контакт: [телеграм](https://t.me/AntonKoshelev)
#
# * Соревнования на Kaggle
# * Разложение спектра красок по базису
# * Интеллектуальное материаловедение
# * Разработка платформы мониторинга востребованности компетенций цифровой экономики
# * Организация проектной деятельности

# %% [markdown]
# ## [Наука с Константином Ушениным](https://vk.com/dl_club_ural)
#
# Контакт: [телеграм-группа](https://t.me/ural_ai)
#
# * Биоинформатика
# * Моделирование органов (сердца)
# * Обработка медецинских сигналов

# %% [markdown]
# ## Наука с Павлом Браславским (для самых жеских)
#
# Контакт: [телега](https://t.me/pbraslavski)
# Курс по [Обработке естественного языка](https://stepik.org/course/1233/info)
#
# * Создание языковых моделей для русского языка
# * Развитие инструментов для обработки русского языка

# %% [markdown]
# ## Проекты Семен Стихин
# * Jupyter расширение для проверки русской орфографии и пунктуации
# * Генерация музыки с помощью Jukebox
# * Генерация blooper роликов со стрима

# %% [markdown]
# # Курсы на лето (а может осень)

# %% [markdown]
# * [Deep Learning МФТИ 1 семестр](https://stepik.org/course/91157/syllabus)
# * [Deep Learning МФТИ 2 семестр](https://stepik.org/course/92488/syllabus)
# * [Курс самсунга по НЛП](https://stepik.org/course/54098/syllabus?auth=registration)
# * [Stanford NLP cs241n](http://web.stanford.edu/class/cs224n/)
# * [Stanford CNN cs231n](http://cs231n.stanford.edu/)
# * [Advanced ML](https://www.coursera.org/specializations/aml)
# * [Deep Learning](https://www.coursera.org/specializations/deep-learning#courses)
# * [NLP](https://www.coursera.org/specializations/natural-language-processing?#courses)

# %% [markdown]
# # Пара 29 мая в Дискорде

# %% [markdown]
# ## 1. Александр Борзунов
# ### Место работы: Yandex.Research
# ### Раньше работал: Yandex Self-driving cars
# ### Бакалавр ФИИТ, ШАД, Сейчас учится в НИУ ВШЭ
#
# <img src="images/sasha.png" style="width: 400px;"/>

# %% [markdown]
# ## 2. Михаил Вяцков
# ### SWE at Facebook VR/AR
# ### ex-Google, ex-Yandex
# ### Бакалавр КН
#
# <img src="images/misha.jpg" style="width: 400px;"/>

# %% [markdown]
# ## 3. Иван Ямщиков
# ### Post-doc in Max Planck Institute for Mathematics in the Sciences
# ### Associate professor @ Higher School of Economics in St. Petersburg
# ### Creative AI and computational creativity, NLP, natural language generation
# ### [Подкаст прогулка](http://t.me/progulka)
#
# <img src="images/ivan.jpg" style="width: 400px;"/>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('2f0wmubTRCc', width=640, height=360)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('d9o_bwo0jJA&t=62s', width=640, height=360)
# Out:
#         <iframe
#             width="640"
#             height="360"
#             src="https://www.youtube.com/embed/d9o_bwo0jJA&t=62s"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
